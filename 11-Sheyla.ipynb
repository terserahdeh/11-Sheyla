# %% [markdown]
# <a href="https://colab.research.google.com/github/terserahdeh/11-Sheyla/blob/main/11-Sheyla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is Sheyla's")
# Out:
# This is Sheyla's
